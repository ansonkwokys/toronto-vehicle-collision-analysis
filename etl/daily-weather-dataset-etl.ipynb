# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)

import os

# %%
daily_weather_df_array = []
for file in os.listdir("../toronto-weather-datasets-daily-2014-2024"):
    if file.endswith(".csv"):
        df = pd.read_csv(f"../toronto-weather-datasets-daily-2014-2024/{file}")
        daily_weather_df_array.append(df)
daily_weather_df = pd.concat(daily_weather_df_array)
daily_weather_df = daily_weather_df.reset_index(drop=True)
daily_weather_df
# Out:
#       Longitude (x)  Latitude (y)    Station Name  Climate ID   Date/Time  \
# 0            -79.63         43.68  TORONTO INTL A     6158731  2024-01-01
# 1            -79.63         43.68  TORONTO INTL A     6158731  2024-01-02
# 2            -79.63         43.68  TORONTO INTL A     6158731  2024-01-03
# 3            -79.63         43.68  TORONTO INTL A     6158731  2024-01-04
# 4            -79.63         43.68  TORONTO INTL A     6158731  2024-01-05
# ...             ...           ...             ...         ...         ...
# 4013         -79.63         43.68  TORONTO INTL A     6158731  2015-12-27
# 4014         -79.63         43.68  TORONTO INTL A     6158731  2015-12-28
# 4015         -79.63         43.68  TORONTO INTL A     6158731  2015-12-29
# 4016         -79.63         43.68  TORONTO INTL A     6158731  2015-12-30
# 4017         -79.63         43.68  TORONTO INTL A     6158731  2015-12-31
#
#       Year  Month  Day  Data Quality  Max Temp (°C) Max Temp Flag  \
# ...

# %%
daily_weather_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4018 entries, 0 to 4017
# Data columns (total 31 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Longitude (x)              4018 non-null   float64
#  1   Latitude (y)               4018 non-null   float64
#  2   Station Name               4018 non-null   object
#  3   Climate ID                 4018 non-null   int64
#  4   Date/Time                  4018 non-null   object
#  5   Year                       4018 non-null   int64
#  6   Month                      4018 non-null   int64
#  7   Day                        4018 non-null   int64
#  8   Data Quality               0 non-null      float64
#  9   Max Temp (°C)              3998 non-null   float64
#  10  Max Temp Flag              24 non-null     object
#  11  Min Temp (°C)              3997 non-null   float64
#  12  Min Temp Flag              25 non-null     object
# ...

# %% [markdown]
# Remove data after Jan 1 2025

# %%
daily_weather_df = daily_weather_df[(daily_weather_df["Year"] != 2025) | ((daily_weather_df["Year"] == 2025) & (daily_weather_df["Month"] == 1) & (daily_weather_df["Day"] == 1))].copy()

# %%
daily_weather_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4018 entries, 0 to 4017
# Data columns (total 31 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Longitude (x)              4018 non-null   float64
#  1   Latitude (y)               4018 non-null   float64
#  2   Station Name               4018 non-null   object
#  3   Climate ID                 4018 non-null   int64
#  4   Date/Time                  4018 non-null   object
#  5   Year                       4018 non-null   int64
#  6   Month                      4018 non-null   int64
#  7   Day                        4018 non-null   int64
#  8   Data Quality               0 non-null      float64
#  9   Max Temp (°C)              3998 non-null   float64
#  10  Max Temp Flag              24 non-null     object
#  11  Min Temp (°C)              3997 non-null   float64
#  12  Min Temp Flag              25 non-null     object
# ...

# %%
def list_all_column_values(df):
    for column_name, column in df.items():
        print(daily_weather_df.value_counts(column_name))
        print(" ")

list_all_column_values(daily_weather_df)
# Out:
# Longitude (x)
# -79.63    4018
# dtype: int64
#
# Latitude (y)
# 43.68    4018
# dtype: int64
#
# Station Name
# TORONTO INTL A    4018
# dtype: int64
#
# Climate ID
# 6158731    4018
# dtype: int64
#
# Date/Time
# 2014-01-01    1
# 2021-05-07    1
# 2021-04-24    1
# 2021-04-25    1
# 2021-04-26    1
#              ..
# 2017-09-06    1
# 2017-09-07    1
# 2017-09-08    1
# 2017-09-09    1
# 2024-12-31    1
# Length: 4018, dtype: int64
#
# Year
# 2016    366
# 2020    366
# 2024    366
# 2014    365
# 2015    365
# 2017    365
# 2018    365
# 2019    365
# 2021    365
# 2022    365
# 2023    365
# dtype: int64
#
# Month
# 1     341
# 3     341
# 5     341
# 7     341
# 8     341
# 10    341
# 12    341
# 4     330
# 6     330
# 9     330
# 11    330
# 2     311
# dtype: int64
#
# Day
# 1     132
# 2     132
# 28    132
# 27    132
# 26    132
# 25    132
# 24    132
# 23    132
# 22    132
# 21    132
# 20    132
# 19    132
# 18    132
# 17    132
# 16    132
# 15    132
# ...

# %% [markdown]
# We would like to add an extra column for displaying the day in unix terms, and then sort the dataset by datetime.

# %%
from datetime import datetime
daily_weather_df["Datetime"] = 0
daily_weather_df["Datetime"] = daily_weather_df.apply(lambda row: int(datetime(row.Year, row.Month, row.Day, 0, 0, 0).timestamp() * 1000), axis=1)
daily_weather_df.sort_values(by=['Datetime'], inplace=True)
daily_weather_df
# Out:
#       Longitude (x)  Latitude (y)    Station Name  Climate ID   Date/Time  \
# 2192         -79.63         43.68  TORONTO INTL A     6158731  2014-01-01
# 2193         -79.63         43.68  TORONTO INTL A     6158731  2014-01-02
# 2194         -79.63         43.68  TORONTO INTL A     6158731  2014-01-03
# 2195         -79.63         43.68  TORONTO INTL A     6158731  2014-01-04
# 2196         -79.63         43.68  TORONTO INTL A     6158731  2014-01-05
# ...             ...           ...             ...         ...         ...
# 361          -79.63         43.68  TORONTO INTL A     6158731  2024-12-27
# 362          -79.63         43.68  TORONTO INTL A     6158731  2024-12-28
# 363          -79.63         43.68  TORONTO INTL A     6158731  2024-12-29
# 364          -79.63         43.68  TORONTO INTL A     6158731  2024-12-30
# 365          -79.63         43.68  TORONTO INTL A     6158731  2024-12-31
#
#       Year  Month  Day  Data Quality  Max Temp (°C) Max Temp Flag  \
# ...
